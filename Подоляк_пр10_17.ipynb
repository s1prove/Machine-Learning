# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from keras.layers import Dropout

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print("x_train original shape", x_train.shape)
print("y_train original shape", y_train.shape)


classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(100,150):
    plt.subplot(5,10,i-100+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(classes[y_train[i][0]])
# Out:
# x_train original shape (50000, 32, 32, 3)
# y_train original shape (50000, 1)

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
    model = keras.Sequential([
        layers.Flatten(input_shape=(32, 32, 3)), 
        layers.Dense(128, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(10, activation="softmax") 
    ])

    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

    model.summary()

    history = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 3072)              0
#
#  dense_34 (Dense)            (None, 128)               393344
#
#  dense_35 (Dense)            (None, 64)                8256
#
#  dense_36 (Dense)            (None, 32)                2080
#
#  dense_37 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 404010 (1.54 MB)
# Trainable params: 404010 (1.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 625/625 [==============================] - 6s 6ms/step - loss: 1.9415 - accuracy: 0.2949 - val_loss: 1.8941 - val_accuracy: 0.3140
# Epoch 2/20
# 625/625 [==============================] - 4s 6ms/step - loss: 1.7452 - accuracy: 0.3717 - val_loss: 1.7363 - val_accuracy: 0.3801
# Epoch 3/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.6639 - accuracy: 0.3973 - val_loss: 1.7003 - val_accuracy: 0.3892
# Epoch 4/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.6047 - accuracy: 0.4243 - val_loss: 1.6242 - val_accuracy: 0.4161
# Epoch 5/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5679 - accuracy: 0.4371 - val_loss: 1.5963 - val_accuracy: 0.4302
# Epoch 6/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5389 - accuracy: 0.4450 - val_loss: 1.6057 - val_accuracy: 0.4271
# Epoch 7/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5151 - accuracy: 0.4573 - val_loss: 1.5553 - val_accuracy: 0.4425
# Epoch 8/20
# 625/625 [==============================] - 3s 6ms/step - loss: 1.4934 - accuracy: 0.4637 - val_loss: 1.5581 - val_accuracy: 0.4448
# Epoch 9/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4767 - accuracy: 0.4686 - val_loss: 1.5481 - val_accuracy: 0.4497
# Epoch 10/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4647 - accuracy: 0.4731 - val_loss: 1.5284 - val_accuracy: 0.4559
# Epoch 11/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4440 - accuracy: 0.4812 - val_loss: 1.5416 - val_accuracy: 0.4482
# Epoch 12/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4304 - accuracy: 0.4858 - val_loss: 1.5136 - val_accuracy: 0.4623
# Epoch 13/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4167 - accuracy: 0.4936 - val_loss: 1.4854 - val_accuracy: 0.4727
# Epoch 14/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4006 - accuracy: 0.4974 - val_loss: 1.4928 - val_accuracy: 0.4717
# Epoch 15/20
# 625/625 [==============================] - 3s 6ms/step - loss: 1.3885 - accuracy: 0.5022 - val_loss: 1.4886 - val_accuracy: 0.4708
# Epoch 16/20
# 625/625 [==============================] - 3s 6ms/step - loss: 1.3811 - accuracy: 0.5059 - val_loss: 1.5065 - val_accuracy: 0.4705
# Epoch 17/20
# 625/625 [==============================] - 3s 6ms/step - loss: 1.3729 - accuracy: 0.5063 - val_loss: 1.4657 - val_accuracy: 0.4842
# Epoch 18/20
# 625/625 [==============================] - 4s 6ms/step - loss: 1.3533 - accuracy: 0.5153 - val_loss: 1.5323 - val_accuracy: 0.4566
# Epoch 19/20
# 625/625 [==============================] - 4s 6ms/step - loss: 1.3472 - accuracy: 0.5183 - val_loss: 1.4853 - val_accuracy: 0.4773
# Epoch 20/20
# 625/625 [==============================] - 3s 5ms/step - loss: 1.3420 - accuracy: 0.5198 - val_loss: 1.4615 - val_accuracy: 0.4839

# %%
# Виведення графіків функції втрат та точності
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("Графік функції втрат")
plt.legend()
plt.grid()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title("Графік точності")
plt.grid()
plt.legend()
plt.show()

# %%
# Оцінка точності на тестовому наборі
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_accuracy*100:.2f}%")

# Розпізнавання 10 випадкових зображень
random_indices = np.random.choice(x_test.shape[0], 10, replace=False)
random_images = x_test[random_indices]
predictions = model.predict(random_images)

# Виведення результатів розпізнавання
for i in range(10):
    predicted_class = np.argmax(predictions[i])
    true_class = np.argmax(y_test[random_indices[i]])
    print(f"Image {i + 1}: Predicted Class {predicted_class}, True Class {true_class}")

# Виведення зображень для перевірки
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(random_images[i], cmap='gray')
    plt.title(f"True: {true_class}, Predicted: {predicted_class}")
    plt.axis('off')
plt.show()
# Out:
# 313/313 - 0s - loss: 1.4410 - accuracy: 0.4915 - 476ms/epoch - 2ms/step
#
# Test Accuracy: 49.15%
# 1/1 [==============================] - 0s 99ms/step
# Image 1: Predicted Class 2, True Class 8
# Image 2: Predicted Class 2, True Class 0
# Image 3: Predicted Class 4, True Class 4
# Image 4: Predicted Class 2, True Class 6
# Image 5: Predicted Class 8, True Class 8
# Image 6: Predicted Class 8, True Class 0
# Image 7: Predicted Class 1, True Class 1
# Image 8: Predicted Class 7, True Class 7
# Image 9: Predicted Class 9, True Class 1
# Image 10: Predicted Class 8, True Class 8

# %%
# Виведення статистики моделі
print("\nModel Evaluation:")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")

# Статистика параметрів моделі
total_parameters = sum([np.prod(layer.get_weights()[i].shape) for layer in model.layers for i in range(len(layer.get_weights()))])

print(f"\nTotal Parameters: {total_parameters}")

# Статистика шарів моделі
for i, layer in enumerate(model.layers):
    print(f"\nLayer {i + 1}: {layer.name}")
    print(f"Number of Parameters: {layer.count_params()}")
    print(f"Input Shape: {layer.input_shape}, Output Shape: {layer.output_shape}")
# Out:
# Model Evaluation:
# Test Loss: 1.4410
# Test Accuracy: 49.15%
#
# Total Parameters: 404010
#
# Layer 1: flatten_9
# Number of Parameters: 0
# Input Shape: (None, 32, 32, 3), Output Shape: (None, 3072)
#
# Layer 2: dense_34
# Number of Parameters: 393344
# Input Shape: (None, 3072), Output Shape: (None, 128)
#
# Layer 3: dense_35
# Number of Parameters: 8256
# Input Shape: (None, 128), Output Shape: (None, 64)
#
# Layer 4: dense_36
# Number of Parameters: 2080
# Input Shape: (None, 64), Output Shape: (None, 32)
#
# Layer 5: dense_37
# Number of Parameters: 330
# Input Shape: (None, 32), Output Shape: (None, 10)

# %% [markdown]
# На практичні роботі була створена модель з 4 Dense-шарами. Було виведено графіки функції втрат і точності під час тренування та розпізнано 10 випадкових зображень з тестового набору. З оцінки моделі можна побачити, що точність тестових даних складає 49.15%. Створена модель не використовує згороткові шари при побудові.
